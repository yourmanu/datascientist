# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Sivakumar**
# --
# Integration Engineer

# %% [markdown]
# *I am interested in Data Science because I like to present stories and make the audience surprised*

# %% [markdown]
# ### Below example will show basic arithmetic operations

# %%
a = 12
b = 2
print(f'a = {a} b = {b}')
print(f'a + b = {a + b}')
print(f'a - b = {a - b}')
print(f'a x b = {a * b}')
print(f'a / b = {a / b}')
print(f'a^b = {a**b}')
# Out:
# a = 12 b = 2
# a + b = 14
# a - b = 10
# a x b = 24
# a / b = 6.0
# a^b = 144

# %% [markdown]
# ## Program to check if a number is prime or not
# ---
#
# [Check original source code here](https://www.programiz.com/python-programming/examples/prime-number#:~:text=In%20the%20above%20program%2C%20our,Otherwise%2C%20the%20number%20is%20prime.)
#
# ```python
#
# num = 407
#
# # To take input from the user
# #num = int(input("Enter a number: "))
#
# # prime numbers are greater than 1
# if num > 1:
#    # check for factors
#    for i in range(2,num):
#        if (num % i) == 0:
#            print(num,"is not a prime number")
#            print(i,"times",num//i,"is",num)
#            break
#    else:
#        print(num,"is a prime number")
#
# # if input number is less than
# # or equal to 1, it is not prime
# else:
#    print(num,"is not a prime number")
# ```
